# %%
# %run compute_virgo.py
# Out:
# 300517927424
# Torsion Subgroup isomorphic to Trivial group associated to the Elliptic Curve defined by y^2 = x^3 - 1706*x + 6320 over Rational Field
# 1
# [(2 : 54 : 1)]
# 0.000000000000000
# 5.71614727018219
# 5.7161472701821916623395660050
# 0.42236269178325809849360427108
# 3.3834352449834279023071420698
# 2
# Basic pair: I=5118, J=-170640
# disc=507124002528
# 2-adic index bound = 4
# 2-adic index = 4
# Two (I,J) pairs
# Looking for quartics with I = 5118, J = -170640
# Looking for Type 2 quartics:
# Trying positive a from 1 up to 15 (square a first...)
# Trying positive a from 1 up to 15 (...then non-square a)
# Trying negative a from -1 down to -11
# Finished looking for Type 2 quartics.
# Looking for Type 1 quartics:
# Trying positive a from 1 up to 27 (square a first...)
# Trying positive a from 1 up to 27 (...then non-square a)
# Finished looking for Type 1 quartics.
# Looking for quartics with I = 81888, J = -10920960
# Looking for Type 2 quartics:
# ...

# %%
# %run analyze_coma.py
# Out:
# PARI stack size set to 8589934592 bytes, maximum size set to 8589934592
# Discriminant Delta: 66702523553344
# Torsion Subgroup: Torsion Subgroup isomorphic to Trivial group associated to the Elliptic Curve defined by y^2 = x^3 - 10141*x + 9980 over Rational Field
# Algebraic Rank: 1
# Generators: [(10987/81 : 774964/729 : 1)]
# L(E, 1): 0.000000000000000
# L'(E, 1) (Standard Precision): 9.67734847088453
# L'(E, 1) (High Precision): 9.6773484708845262045292746241
# Real Period (Omega): 0.26217654321413055598324986640
# Regulator (Height of P): 9.2278931137830956453031786471
# Product of Tamagawa Numbers: 2
#
# Initiating Verbose 2-Descent on E_coma:
# Basic pair: I=30423, J=-269460
# disc=112560508496268
# 2-adic index bound = 4
# 2-adic index = 4
# Two (I,J) pairs
# Looking for quartics with I = 30423, J = -269460
# Looking for Type 2 quartics:
# Trying positive a from 1 up to 34 (square a first...)
# Trying positive a from 1 up to 34 (...then non-square a)
# ...

# %%
# %run acsc_ecc.py
# Out:
# SageMath version: 10.7
# gudhi.wasserstein_distance not available. Using fallback.
# gudhi.SimplexTree.cochain_complex not available. Using fallback.
# imageio not installed. MP4 generation will be skipped. Run: pip install imageio
# Step 1: Configuration
# Step 2: Data Loading
# Step 2: Data Loading
# Summary: {'Initial Rows': 866000, 'NaN Counts': {'logmass': 0, 'metallicity': 0, 'petrorad_r': 0, 'ra': 0, 'dec': 0, 'z': 0}}
# Step 3: Chunk Processing
# Processing chunks: 100%|████████████████████| 87/87 [02:57<00:00,  2.04s/it]
# Step 3: Chunk Processing
# Summary: {'Rows Processed': 866000}
# Step 4: Sequence Analysis
# Step 4: Sequence Analysis
# Summary: {'a': {'Power_of_Prime_Ratio': 0, 'Fibonacci_Like_Ratio': 0, 'Arithmetic_Ratio': 0, 'Geometric_Ratio': 0}, 'b': {'Power_of_Prime_Ratio': 0, 'Fibonacci_Like_Ratio': 0, 'Arithmetic_Ratio': 0, 'Geometric_Ratio': 0}, 'power_of_2': {'Power_of_Prime_Ratio': 0, 'Fibonacci_Like_Ratio': 0, 'Arithmetic_Ratio': 0, 'Geometric_Ratio': 0}}
# ...

# %%
# %run robust_acsc_ecc_v17.py
# Out:
# SageMath version: 10.7
# gudhi.wasserstein_distance not available. Using fallback.
# gudhi.SimplexTree.cochain_complex not available. Using fallback.
# imageio not installed. Using matplotlib FFMpegWriter for MP4 generation.
# Step 1: Configuration
# Step 2: Data Loading
# Step 2: Data Loading
# Summary: {'Initial Rows': 866000, 'NaN Counts': {'logmass': 0, 'metallicity': 0, 'petrorad_r': 0, 'ra': 0, 'dec': 0, 'z': 0}}
# Step 3: Chunk Processing
# Processing chunks: 100%|████████████████████| 87/87 [01:04<00:00,  1.36it/s]
# Step 3: Chunk Processing
# Summary: {'Rows Processed': 188250}
# Step 4: Sequence Analysis
# Step 4: Sequence Analysis
# ...

# %%
# %run ecc_advanced_analysis_v6.py
# Out:
# 2025-10-09 01:44:09,183 - INFO - STEP 0: Starting 3-Selmer Ground Truth Solver (V6 - Robust Boundary Check) starting...
# 2025-10-09 01:44:09,184 - INFO - Targeting first 50000 rows with 300s timeout per curve.
# 2025-10-09 01:44:09,185 - INFO - STEP 1: Data Loading and Sampling (N=50000) starting...
# 2025-10-09 01:44:09,240 - INFO - STEP 1: Data Loading and Sampling starting...
# 2025-10-09 01:44:09,241 - INFO - Step 1 Summary: {'Total Rows Loaded': 50000, 'Valid Rows for Analysis': 50000, 'Source File': 'GalSpecExtra.csv'}
# 2025-10-09 01:44:09,242 - INFO - STEP 2: Elliptic Curve Coefficient Mapping starting...
# --- STEP 0: Starting 3-Selmer Ground Truth Solver (V6 - Robust Boundary Check) ---
#
# --- STEP 1: Data Loading and Sampling (N=50000) ---
#
# --- STEP 1: Data Loading and Sampling ---
#
# --- STEP 2: Elliptic Curve Coefficient Mapping ---
# 2025-10-09 01:44:14,518 - INFO - STEP 2: Elliptic Curve Coefficient Mapping starting...
# ...
